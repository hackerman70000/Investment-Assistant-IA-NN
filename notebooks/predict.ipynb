# %%
# !git clone https://github.com/hackerman70000/Prophet-IA-NN.git
# Out:
# Cloning into 'Investment-Prophet-NN'...
# remote: Enumerating objects: 245, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 245 (delta 68), reused 127 (delta 46), pack-reused 95 (from 1)
# Receiving objects: 100% (245/245), 62.44 KiB | 1.42 MiB/s, done.
# Resolving deltas: 100% (116/116), done.

# %%
# %cd /content/Prophet-IA-NN
# Out:
# /content/Investment-Prophet-NN

# %%
import sys
sys.path.append('/content/Prophet-IA-NN')

# %%
# !mkdir models/prediction/

# %%
# !python src/prediction/predict.py
# Out:
# 2024-09-01 16:51:36.030956: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-01 16:51:36.055607: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-01 16:51:36.062702: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-01 16:51:36.079587: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
